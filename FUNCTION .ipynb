# %% [markdown]
# ### **Theory Questions:**

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
#   -> In Python, the main difference between a function and a method is that a function is independent and can be called from anywhere, while a method is tied to an object or class.
#
# Function ex: def greet(name):
#   print(f"Hello,{name}!")
#
#
# Methods ex:  append(), count(), Pop(),extend().

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python
#
#   -> Parameters :
# These are the variables listed inside the parentheses in the function definition. They define the type and number of inputs a function can accept. Parameters are part of the function's signature and are local to the function where they are defined.
#
# ex: len("a,b,c")
# the "a,b,c" is a parameter value.
#
# Arguments :
# These are the values that are passed to the function when it is called. Arguments provide the flexibility to pass different values to a function, allowing for dynamic execution. Arguments can be any scope, including variables that exist outside the function or literals.
#
# ex:- def say_hello("my_name"):
#   print("hello", my_name)

# %% [markdown]
# 3. What are the different ways to define and call a function in Python
#
#   -> To define a function in Python, you can use the def keyword, followed by the function name, parameters, and the function body.
#
#   ex:- def my_function():
#       print("Hello from a function")
#
#
#    To call a function, you can use the function name followed by parentheses.
#
#   ex:- my_function().

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#
#   -> The purpose of the return statement in Python is to exit a function and send a value back to the caller.
#
#   ex:- return total_marks(marks_list)

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
#   -> An Iterable is basically an object that any user can iterate over. We can generate an iterator when we pass the object to the iter() method.
#
#   iterable ex:- list[1, 2, 3,4]
#
#   iterator ex:- a = iter(s)

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined
#
#   -> A generator in Python is a function that generates a sequence of values by using the yield keyword instead of the return keyword.
#
#   A generator function returns an iterator object that can be looped through using a for loop. The generator produces values one at a time, and retains its state between successive yields. This allows it to resume where it left off.
#
#   ex:- my_gen = (x**2 for x in range(10) if x%2 == 0).

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
#   -> Generators in Python have several advantages over regular functions, including:
# Memory efficiency: Generators are memory-efficient because they only compute values when needed.
# Readability: Generators can lead to more readable and concise code.
# Speed: Generators can improve performance and responsiveness in applications.
# Infinite streams of data: Generators can represent infinite streams of data.
# On-demand values: Generators can return multiple values, one after another, on-demand.
# Lazy evaluation: Generators compute values only when needed.
#
# ex:- def fib(num).

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
#   -> In Python, a lambda function is a small, anonymous function that is created on the fly.
#
#    It is used when a function is needed for a short period of time or when creating a full-fledged function using def would be overkill.
#
#    ex:- len = lambda x: length(x).

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python
#
#   -> The Python map() function applies a function to each item in an iterable, such as a list, tuple, or dictionary, to create a new iterable. The map() function is a built-in function that can help reduce code size and make it run faster by avoiding the use of loops.
#
#   ex:- list(map(lambda x: x**2)).

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#   -> Map applies a given function to each item of an array and returns a new array. Filter creates a new array with all elements that pass a test implemented by the provided function. Reduce applies a function against an accumulator and each element in the array (from left to right) to reduce it to a single output value.
#
#   examples:- Map => list(map(lambda x:x**2))
#
#   Reduce => reduce(lambda x, y: x+y,1)
#
#   Filter => list(filter(check_even,num)).

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13]
#
#   -> https://drive.google.com/file/d/1aUxePeY4iC8MMHXNgKSm1l6AJALUXjDf/view?usp=drive_link

# %% [markdown]
# # Practical Questions:

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in


def sum_even_numbers(numbers):
    sum_even_numbers = 0

    for num in numbers:
      if num % 2 == 0:
        sum_even_numbers += num
        return sum_even_numbers

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string
def reverse_string(input_string):
    reversed_str = ""
    for char in input_string:
        reversed_str = char + reversed_str
    return reversed_str

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
each number

def square_numbers(numbers):
  squared_numbers = []
  for num in numbers:
    squared_numbers.append(num**2)
  return squared_numbers.

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
number = int(input("Enter a number: "))
flag = False

for i in range(2, 200):
    if (number % i) == 0:
        flag = True
        break

if flag:
    print(number, "is not a prime number")
else:
    print(number, "is a prime number")
# Out:
# Enter a number: 157
# 157 is not a prime number

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms
def fib(n):
  a = 0
  b = 1
  for i in range(n):
    # if n = 5,0,1,2,3,4
    yield a # indented to be part pf the loop
  a,b = b,a+b # Indented to be part of the loop
  f = fib(5)
  for i in f:
    print(i)

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent
def power_generator(base, exponent):
    result = 1
    for i in range(exponent + 1):
        yield result
        result *= base

# Accept input from the user
base = int(input("Input the base number: "))
exponent = int(input("Input the exponent: "))

# Create the generator object
power_gen = power_generator(base, exponent)

# Generate and print the powers
print(f"Powers of {base} up to exponent {exponent}:")
for power in power_gen:
    print(power)
# Out:
# Input the base number: 2
# Input the exponent: 3
# Powers of 2 up to exponent 3:
# 1
# 2
# 4
# 8

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string
def read_file_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
# Create a list of tuples named 'subject_marks', each tuple containing a subject and its corresponding marks
subject_marks = [('English', 88), ('Science', 90), ('Maths', 97), ('Social sciences', 82)]

# Display the original list of tuples to the console
print("Original list of tuples:")
print(subject_marks)

# Sort the 'subject_marks' list of tuples based on the second element of each tuple (the marks),
# using a lambda function as the sorting key to extract the second element
subject_marks.sort(key=lambda x: x[1])

# Display the sorted list of tuples to the console
print("\nSorting the List of Tuples:")
print(subject_marks)
# Out:
# Original list of tuples:
# [('English', 88), ('Science', 90), ('Maths', 97), ('Social sciences', 82)]
#
# Sorting the List of Tuples:
# [('Social sciences', 82), ('English', 88), ('Science', 90), ('Maths', 97)]

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit
# Temperature in celsius degree
celsius = 37

# Converting the temperature to
# fehrenheit using the formula
fahrenheit = (celsius * 1.4) + 37

# printing the result
print('%.2f Celsius is equivalent to: %.2f Fahrenheit'
      % (celsius, fahrenheit))
# Out:
# 37.00 Celsius is equivalent to: 88.80 Fahrenheit

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string
str = ['a','hello', 'e', 'i', 'o', 'u', 'apple']
vowels = ['a','e','i','o','u']

list(filter(lambda x: x not in vowels, str))
# Out:
# ['hello', 'apple']

# %%
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.

# Write a Python program using lambda and map.
def return_order_list(order_list):
    return list(map(lambda x: (x[0], x[1] * x[2] + 10 if x[1] * x[2] < 100 else x[1] * x[2]), order_list))

# Call the function with the order list
result = return_order_list([(5532,77,98.52),(3321,98,150.25)])
print(result)  # Print the result

# Second function (corrected indentation and removed unreachable code)
def return_order_list(order_list):
    tuples = []
    # This loop is now correctly indented
    for i in order_list:
        if type(i) == tuple:
            tuples.append(i)
    return tuples  # Return the tuples

# Call the second function
result2 = return_order_list([(5532,88,98.52),(3321,98,150.25)])
print(result2)  # Print the result
# Out:
# [(5532, 7586.04), (3321, 14724.5)]
# [(5532, 88, 98.52), (3321, 98, 150.25)]
